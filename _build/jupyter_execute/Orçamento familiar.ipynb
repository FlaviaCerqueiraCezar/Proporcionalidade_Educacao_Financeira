# %% [markdown]
# ## Planejamento Financeiro Familiar

# %% [markdown]
# O planejamento financeiro nos permite compreender nossa situação financeira, identificando para onde o dinheiro está indo e possibilitando decisões mais conscientes sobre os gastos. O método 50-30-20 é uma abordagem de orçamento que divide a renda líquida mensal em três partes: $50\%$ para necessidades (despesas essenciais e obrigatórias), $30\%$ para desejos (gastos flexíveis e não essenciais, como lazer) e $20\%$ para reservas financeiras (poupança, investimentos ou quitação de dívidas).
#
# $$\textbf{I - Para recordar}$$
# **1.** Para preparar um bom orçamento familiar primeiramente é necessário saber quais são as despesas habituais e como é possível economizar. É importante também saber a renda da família e estabelecer quanto será destinado a cada uma delas.
#
# **a)** Liste 5 tipos de despesas comuns em uma família.
#
# **b)** Expliqeu o que significa as expressões:
#
# * “$10\%$ de desconto no produto"
#
# * “$30\%$ do salário para moradia"
#
# **c)** Todos os recebimentos são chamados de renda. Qual a diferença de renda fixa e renda variável? Dê exemplos.

# %% [markdown]
# ```{admonition} Sugestão!
# :class: tip, dropdown
# **a)** Água,...
#
# **b)** Ambas as frases indicam certa parte de um todo. Desconto refere-se a redução no preço total.
#
# **c)** Fixa é que permanece igual. Variável é mutável ou sofre alterações.

# %% [markdown]
# $$\textbf{II - Compreender a aplicaçao}$$
#
# **Atividade 1**
#
# Considere um salário de $R\$ 2000,00$. Classifique os seguintes gastos considerando as categorias:
#
# **I-NECESSIDADES**; **II-DESEJOS** e  **III-RESERVAS**
#
# * Moradia: $R\$ 600,00$
#
# * Mercado: $R\$ 500,00$
#
# * Transporte: $R\$ 300,00$
#
# * Lazer: $R\$ 200,00$
#
# * Gastos diversos: $R\$ 100,00$
#
# * Poupança: $R\$ 300,00$
#
# **a)** Qual valor total destinado a cada categoria?
#
# **b)** Qual a porcentagem de cada despesa em relação ao salário?

# %% [markdown]
# ```{admonition} Confira sua resposta!
# :class: tip, dropdown
# **a)** Necessidades $= 600+500+300 = 1400$. Desejos $= 200+100 = 300 $ e Reservas $=300$
#
# **b)** Necessidades: $\frac{1400}{2000} \cdot 100 = 70\%$, Desejos: $\frac{300}{2000} \cdot 100 = 15\%$, Reservas: $15\%$

# %% [markdown]
# **2.** Qual despesa ocupa a maior fatia desse orçamento? Em sua opinião essa é a despesa mais importante? Por quê?

# %% [markdown]
# ```{admonition} Confira sua resposta!
# :class: tip, dropdown
#
# Moradia ($30\%$). É uma **Necessidade**, logo é importante.

# %% [markdown]
# Observe no gráfico 1 as categorias de renda, comparando a situação anterior com o idealizado pelo método 50/30/20 de organização dos gastos.

# %%
# %%html
# <iframe style="margin-top:0px;margin-left:-20px;" src="https://www.desmos.com/calculator/jm0ytub5as" width="1200" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>
# Out:
# <iframe style="margin-top:0px;margin-left:-20px;" src="https://www.desmos.com/calculator/jm0ytub5as" width="1200" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>

# %% [markdown]
# **3.** Quais as diferenças percentuais ($\%$) entre o idealizado pelo método 50/30/20 de cada categoria e o orçamento apresentado na Atividade 1?

# %% [markdown]
# ```{admonition} Confira sua resposta!
# :class: tip, dropdown
#     Necessidade = $ 20\%$
#
#     Desejos = $ - 15%$
#
#     REservas = $-5%$

# %% [markdown]
# $$\textbf{III - Aplicar o conhecimento (Resolver)}$$
#
# **Agora vejamos os Perfis de três famílias hipotéticas**

# %% [markdown]
# ```{dropdown} Exemplo **Família Silva**
#
# A Família Silva é formada por um casal e uma filha de 7 anos. Ambos os pais trabalham com carteira assinada e recebem juntos uma renda mensal fixa de $R\$ 3.200,00$. A principal despesa da família é a moradia, com o pagamento do aluguel, água e luz totalizando $R\$ 1.000,00$. Além disso, gastam cerca de $R\$ 800,00$ no supermercado, $R\$ 400,00$ com transporte, e $R\$ 500,00$ com a educação da filha, incluindo material escolar e atividades extracurriculares. Para o lazer, reservam $R\$ 200,00$ ao mês, além de  $R\$ 150,00$ para saúde e $R\$ 150,00$ em outros gastos diversos. A renda é estável, mas o orçamento é bem comprometido pelas despesas fixas, deixando pouco espaço para poupança.
#
# Composição: Casal com 1 filho (7 anos).

# %% [markdown]
# **4.** Analisando o orçamento da família:
#
# **a)** Qual o valor destinado à reserva de emergência (poupar)?
#
# **b)** Qual despesa poderia entrar no radar de economia dessa família?

# %% [markdown]
# ```{dropdown} Exemplo **Família Oliveira**
#
# A Família Oliveira é composta por uma mãe solo e seu filho de 5 anos. A mãe trabalha como autônoma, realizando serviços e freelancers, e por isso sua renda é variável, girando em torno de $R\$ 2.500,00$ por mês, mas podendo cair para $R\$ 2.000,00$ ou chegar a $R\$ 3.000,00$ em meses melhores.
#  Entre as despesas, estão $R\$ 900,00$ com moradia, $R\$ 700,00$ com supermercado, e $R\$ 350,00$ com transporte. A educação da criança gera um gasto de $R\$ 400,00$ mensais, entre creche e materiais. Além disso, há despesas de $R\$ 150,00$ com lazer, $R\$  150,00$ com plano de saúde e $R\$ 200,00$ em outros gastos.
#  O desafio dessa família é a instabilidade da renda: em meses de ganho menor, o orçamento fica bastante apertado, exigindo alguns cortes nas despesas variáveis.
#
#  Composição: Mãe solo com 1 filho (5 anos).

# %% [markdown]
# **5.** Analisando o orçamento da família:
#
# **a)** Qual o valor destinado à reserva de emergência (poupar)?
#
# **b)** Qual despesa poderia entrar no radar de economia dessa família?

# %% [markdown]
# ```{dropdown} Exemplo **Família Santos**
#
# A Família Santos é formada por um casal e dois filhos adolescentes, de 12 e 15 anos. O casal possui empregos estáveis, com renda conjunta fixa de $R\$ 5.500,00$ mensais.
#  O maior gasto da família é com a moradia (água, luz, aluguel e condomínio) valor de $R\$ 1.500,00$. O gasto da família no supermercado custa cerca de $R\$ 1.200,00$ ao mês, e o transporte (combustível) $R\$ 600,00$. Uma parte significativa do orçamento é destinada à educação dos filhos, que estudam em escola particular e fazem cursos extracurriculares, somando $R\$ 1.000,00$. Além disso, a família separa $R\$ 400,00$ para lazer, $R\$ 300,00$ para plano de saúde e outros $R\$ 300,00$ para despesas diversas.
#  Apesar da renda maior, as responsabilidades financeiras com os filhos tornam o orçamento bastante comprometido, exigindo organização para que ainda consigam reservar parte para poupança.
#
# Composição: Casal com 2 filhos (12 e 15 anos).

# %% [markdown]
# **6.** Analisando o orçamento da família:
#
# **a)** Qual o valor destinado à reserva de emergência (poupar)?
#
# **b)** Qual despesa poderia entrar no radar de economia dessa família?

# %% [markdown]
# ```{admonition} Confira suas respostas!
# :class: tip, dropdown
#
# **3.** Família Silva: **a)** Nada. **b)** Lazer, Outros ou renegociação de moradia, educação pode ser analisada, mas é despesa sensível
#
# **4.** Família Oliveira: **a)** Nada. **b)** Lazer e outros.
#
# **5.** Família Santos: **a)** $R\$200,00$. **b)** Lazer ou Outros, também é possível reavaliar custos educacionais e transporte

# %% [markdown]
# **7.** Qual família gasta mais proporcionalmente com moradia?

# %% [markdown]
# ```{admonition} Sugestão!
# :class: tip, dropdown
#     Divida o valor gasto com moradia pela renda da família

# %% [markdown]
# **Atividade 2**
#
# **a)** Liste as categorias de despesas, conforme nomenclatura do método 50-30-20, de cada umas das famílias fictícias.
#
# **b)** Calcule a porcentagem de cada categoria de despesa em relação à renda total de cada família.

# %% [markdown]
# ```{admonition} Confira suas respostas!
# :class: tip, dropdown
# **a)**
# * NECESSIDADES: Moradia, Mercado, Transporte, Educação, Saúde.
#
# * DESEJOS: Lazer, Outros.
#
# * RESERVA: Reserva financeira, poupança, investimento
#
# **b)**
# * Família Silva - Necessidades: 89,07%, Desejos: 10,94%, Poupança: 0%.
#
# * Família Oliveira (considerando a média salarial de $R\$ 2.500$)- Necessidades: 100%, Desejos: 14%, Poupança: 0%.
#
# * Família Souza - Necessidades: 83,63%, Desejos: 12,72%, Poupança: 3,64%.

# %% [markdown]
# **Atividade 3**
#
# Use o gráfico 2 para simular outras situações, aumentando os gastos com necessidades e desejos, desconsiderando os limites percentuais.
#
# **a)** O que acontece com a barra de reserva quando o gasto com necessidades e/ou desejos ultrapassa a linha de valor ideal?
#
# **b)** O que acontece com a barra de reserva quando a soma entre os valores gastos com necessidade e desejos ultrapassa o valor total da renda?
#
# **c)** O que cada situação representa para a proporção idealizada do orçamento?
#
# **d)** Utilize os *sliders* R, N e D (controles deslizantes), para conferir suas respostas com relação a variável P (poupar)) das famílias Silva, Oliveira e Santos.

# %% [markdown]
# ```{admonition} Compare suas respostas!
# :class: tip, dropdown
# **a)** A barra de reserva diminui, pois uma parte do dinheiro que deveria ser destinada à poupança passa a ser usada para cobrir gastos maiores com necessidades ou desejos.
#
# **b)** A barra de reserva se torna negativa, indicando que não há possibilidade de poupar e que a família pode estar gastando mais do que ganha.
#
# **c)** Mostram desequilíbrio da proporção ideal do orçamento, pois os gastos deixam de respeitar a divisão planejada, comprometendo a poupança e a organização financeira da família, gerando um quadro de endividamento.
#
# **d)** Ao ajustar os sliders, observa-se que, à medida que os gastos com necessidades (N) e desejos (D) aumentam, o valor destinado a poupar (P) diminui ou desaparece, confirmando que o excesso de gastos afeta diretamente a reserva financeira das famílias Silva, Oliveira e Santos.

# %%
# %%html
# <iframe style="margin-top:0px;margin-left:-20px;" src="https://www.desmos.com/calculator/8a7zmbsekx" width="1200" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>
# Out:
# <iframe style="margin-top:0px;margin-left:-20px;" src="https://www.desmos.com/calculator/8a7zmbsekx" width="1200" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>

# %% [markdown]
# **Atividade 4** (usando a Calculadora Desmos)
#
# **a)** Baseado nos modelo dos gráficos 1 e 2, acrescente os casos das famílias separando por categorias de renda, gastos e valores, contendo:
#
# *  Tipo de renda: fixa ou variável
#
# * Despesas (separando por categorias do método 50/30/20) Moradias, Alimentação, Transporte, Educação (escola/atividades), Lazer, Saúde e Outros.
#
# **b)** A partir do gráfico, represente as porcentagens do orçamento de cada categoria.

# %% [markdown]
# ```{admonition} Confira suas respostas!
# :class: tip, dropdown
#
# **a)** e **b)**
#
#  **Perfis das Famílias**
#
# Considerando resumidamente a situação de cada família citada acima:
#
# **1 - Família Silva**
#
# **Renda:** $R\$ 3.200,00$ fixos (salário do pai e da mãe).
#
# **Despesas**
#
# * NECESSIDADES: Despesas essenciais para a manutenção da família.
#
# Moradia: $R\$ 1.000$, Mercado (Alimentação): $R\$ 800$, Transporte: $R\$ 400$, Educação (escola/atividades): $R\$ 500$, Saúde: $R\$ 150$.
#
# Total: $R\$ 2.850$ → 89,06% da renda
#
# * DESEJOS: Despesas não essenciais, mas importantes para o bem-estar.
#
# Lazer: $R\$ 200$, Outros: $R\$ 150$.
#
# Total: $R\$ 350$ → 10,94% da renda
#
# * POUPANÇA / RESERVA
#
# Reserva: $R\$ 0$
#
# **2 - Família Oliveira**
#
# **Renda:** Renda variável (média $R\$2.500,00$, mas pode variar de $R\$ 2.000$ a $R\$ 3.000$).
#
# **Despesas:
#
# * NECESSIDADES: Moradia: $R\$ 900$, Mercado (Alimentação): $R\$ 700$, Transporte: $R\$ 350$, Educação (creche e materiais): $R\$ 400$, Saúde: $R\$ 150$.
#
# Total: $R\$ 2.500$ → 100% da renda
#
# * DESEJOS: Lazer: $R\$ 150$, Outros: $R\$ 200$.
#
# Total: $R\$ 350$ → 14% da renda
#
# * POUPANÇA / RESERVA
#
# Reserva: $R\$ 0$
#
# **3- Família Santos**
#
# **Renda:** $R\$ 5.500,00$ fixos.
#
# **Despesas**
#
# * NECESSIDADES: Moradia: $R\$ 1.500$, Mercado (Alimentação): $R\$ 1.200$, Transporte: $R\$ 600$, Educação (escola/atividades): $R\$ 1.000$, Saúde: $R\$ 300$
#
# Total: $R\$ 4.600$ → 83,64% da renda
#
# * DESEJOS: Lazer: $R\$ 400$, Outros: $R\$ 300$.
#
# Total: $R\$ 700$ → 12,73% da renda
#
# * POUPANÇA / RESERVA (20%)
#
# Total: $R\$ 200$ → 3,64% da renda

# %% [markdown]
# **Atividade 5: Análise de casos**
#
# O grafico 3 representa os pontos que relacionam cada valor com o tipo de gasto das três famílias.
#
# **a)** Analisando cada tipo de despesa das família, compare qual foi a família com maior valor gasto para cada categoria.
#
# **b)** Considerando o salário de cada família e o ranking de gastos, como se justifica a situação.
#
# **c)** Comparando as principais proporções, qual a família com maior propensão a descontrole financeiro? Justifique.

# %% [markdown]
# ```{admonition} Sugestão!
# :class: tip, dropdown
#
# **a)** Observe, para cada categoria de gasto, qual ponto está mais alto no gráfico. Compare família por família dentro da mesma categoria e identifique quem gastou mais em cada tipo de despesa.
#
# **b)** Relacione os valores gastos com o salário total de cada família. Pense se o maior gasto ocorre porque a renda é maior ou se representa uma parcela muito grande do orçamento, mesmo com renda menor.
#
# **c)** Analise quanto do salário cada família destina às principais categorias. Observe se alguma delas apresenta gastos elevados em relação à renda, pouca margem para poupar ou desequilíbrio entre necessidades, desejos e reserva.

# %%
# %%html
# <iframe style="margin-top:0px;margin-left:-20px;" src="https://www.desmos.com/calculator/ryktixj41d" width="1200" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>
# Out:
# <iframe style="margin-top:0px;margin-left:-20px;" src="https://www.desmos.com/calculator/ryktixj41d" width="1200" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>

# %% [markdown]
# **8.** Agora com relação a análise realiza:
#
# **a)** Qual despesa ocupa a maior fatia do orçamento das famílias?
#
# **b)** Qual família tem criado uma reserva financeira?
#
# **c)** Em qual família o lazer ocupa a maior fatia do orçamento?
#
# **d)** Alguma das famílias está seguindo o método 50-30-20.

# %% [markdown]
# ```{admonition} Confira suas respostas!
# :class: tip, dropdown
# **a)** A despesa com moradia é a que ocupa a maior fatia do orçamento das famílias, pois representa um gasto fixo elevado e prioritário em relação às demais categorias.
#
# **b)** A família Oliveira apresenta um valor positivo destinado à poupança, mesmo após considerar os gastos com necessidades e desejos.
#
# **c)** Família Santos, indicando uma proporção elevada de gastos com desejos em relação à renda total.
#
# **d)** Nenhuma das famílias segue exatamente o método 50/30/20, pois há desequilíbrios entre as proporções de necessidades, desejos e poupança, especialmente pela redução ou ausência de reserva financeira em algumas delas.

# %% [markdown]
# $$\textbf{IV -Analisar (Comparar)}$$
#
#
# **Atividade 6**
#
# Compare a Família Oliveira (renda variável, sem filhos) e a Família Silva (renda fixa, com filho).
#
# **a)** Quem tem maior comprometimento da renda com alimentação?
#
# **b)** Quem teria mais dificuldade em poupar em caso de emergência?
#
# **c)** Construa os gráficos na calculadora Desmos, lado a lado para comparação.

# %%
# %%html
# <iframe style="margin-top:0px;margin-left:-20px;" src="https://www.desmos.com/calculator/aqfy8wd4b6" width="1200" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>
# Out:
# <iframe style="margin-top:0px;margin-left:-20px;" src="https://www.desmos.com/calculator/aqfy8wd4b6" width="1200" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>

# %% [markdown]
# ```{admonition} Sugestão!
# :class: tip, dropdown
# **a)** Observe qual porcentagem do salário é destinada a essa despesa em cada famílias, não apenas o valor em reais.
#
# **b)** Analise a estabilidade da renda e a existência (ou não) de sobra mensal no orçamento. Pense em como despesas fixas e a presença de dependentes influenciam a capacidade de reagir a imprevistos.
#
# **c)** Represente as categorias de gastos no mesmo padrão (gráfico de barras) para as duas famílias. Use a mesma escala e organize os gráficos lado a lado para facilitar a comparação visual das proporções.

# %% [markdown]
# **Atividade 7:**
#
# Imagine que o salário aumente para $R\$ 2.500,00$ em cada famílias, mas os gastos permanecem os mesmos.
#
# **a)** Como mudam as porcentagens de cada categoria por família?
#
# **b)** A despesa com moradia continua proporcional ao salário?

# %% [markdown]
# ```{admonition} Sugestão!
# :class: tip, dropdown
# No gráfico 2 atualize os valores da renda e compare os dois gráficos lado a lado.
#
# **a)** Com o aumento do salário e os gastos iguais, todas as despesas passam a representar uma porcentagem menor do salário.
#
# **b)** Não. A despesa com moradia não continua proporcional, pois o valor gasto é o mesmo, mas o salário aumentou. Assim, a moradia passa a ocupar uma parte menor da renda

# %% [markdown]
# $$\textbf{V - Analisando a situação(Avaliar)}$$
#
#
# **Atividade 8:**
#
# Compare dois perfis de gastos:
#
# **Pessoa A**: Gasta $50\%$ com moradia (aluguel, água, luz e alimentação), $30\%$ em lazer, $20\%$ em outros.
#
# **Pessoa B**: Segue a regra 50-30-20 ($50\%$ necessidades, $30\%$ desejos, $20\%$ poupança).
#
# Qual perfil é mais sustentável financeiramente? Justifique com base em proporcionalidade e porcentagem.

# %% [markdown]
# ```{admonition} Compare sua resposta!
# :class: tip, dropdown
# A Pessoa B é mais sustentável financeiramente, pois segue a regra 50-30-20 e reserva $2\0%$ da renda para poupança. Já a Pessoa A gasta $100\%$  do salário, sem criar reserva, o que pode gerar dificuldades em caso de imprevistos.

# %% [markdown]
# **9.** Voltemos para a análise da três famílias: considere a regra 50-30-20 (necessidades $50\%$, desejos $30\%$, poupança $2\0%$).
#
# **a)** Qual família mais se aproxima dessa distribuição?
#
# **b)** Se a Família Santos quiser poupar $20\%$ da renda, onde poderiam reduzir despesas?

# %% [markdown]
# ```{admonition} Confira suas resposta!
# :class: tip, dropdown
# **a)** A família Oliveira é a que mais se aproxima da regra 50-30-20, pois apresenta uma distribuição mais equilibrada entre necessidades, desejos e poupança.
#
# **b)** Para poupar $20\%$ da renda, a família Santos poderia reduzir principalmente as despesas com desejos, como lazer e gastos não essenciais, ajustando essas categorias para liberar recursos para a poupança.

# %% [markdown]
#  $$\textbf{VI - Criar (Elaborar)}$$
#
# **Atividade 9**
#
# Reorganize do orçamento de uma das famílias, criando uma nova distribuição mais equilibrada.
#
# **Atividade Final no Desmos:**
#
# **a)** Elabore uma carteira pessoal de gastos (50-30-20 ou outra proporção definida por você).
#
# **b)** Use o modelo abaixo (gráfico de barras) para comparar seu modelo com o ideal sugerido.
#
# **c)** Use os *sliders* na planilha da Calculadora Desmos abaixo para simular aumento/diminuição do salário e observe como as proporções se ajustam.

# %% [markdown]
# ```{admonition} Sugestão!
# :class: tip, dropdown
#
# **a)** Defina primeiro qual proporção do salário será destinada a necessidades, desejos e poupança. Pense em quais despesas são essenciais e quais podem ser ajustadas, mantendo um equilíbrio entre consumo e reserva.
#
# **b)** Construa os dois gráficos usando a mesma escala. Observe as diferenças nas alturas das barras e reflita sobre quais categorias estão acima ou abaixo do modelo ideal.
#
# **c)** Ajuste o valor da renda e observe como as porcentagens mudam, mesmo quando os gastos permanecem fixos. Analise quais categorias se tornam mais ou menos representativas no orçamento e como isso afeta a poupança.

# %% [markdown]
# **10.** Em dupla ou grupos discuta e reponda:
#
# **a)** Como pequenas mudanças em categorias (ex.: reduzir lazer de 30% para 20%) impactam no valor disponível para poupança?
#
# **b)** Que estratégias ajudam a equilibrar o orçamento?
#
# **c)** Como a presença de filhos altera as proporções das despesas.

# %% [markdown]
# ```{admonition} Sugestão!
# :class: tip, dropdown
#
# **a)** Pense em quanto sobra do salário quando uma categoria é reduzida e como essa diferença pode ser direcionada para a poupança.
#
# **b)** Reflita sobre priorizar gastos essenciais, definir limites para desejos e planejar a poupança antes de gastar.
#
# **c)** Observe que a presença de filhos aumenta despesas fixas (alimentação, educação, saúde), exigindo reorganização das proporções do orçamento.

# %%
# %%html
# <iframe style="margin-top:0px;margin-left:-20px;" src="https://www.desmos.com/calculator/t0961irwz5" width="1200" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>
# Out:
# <iframe style="margin-top:0px;margin-left:-20px;" src="https://www.desmos.com/calculator/t0961irwz5" width="1200" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>

# %% [markdown]
# **DESAFIO FINAL**
#
# Relatório escrito ou apresentação da sua carteira pessoal com:
#
# * Os cálculos percentuais.
#
# * O gráfico gerado no Desmos.
#
# * Reflexões sobre escolhas financeiras sustentáveis para cada família.
